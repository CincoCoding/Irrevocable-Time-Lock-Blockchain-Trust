# %%
################################################################################
# Import libraries
################################################################################
import os
import json
from web3 import Web3
from pathlib import Path
from dotenv import load_dotenv
import streamlit as st
import web3



# Load .env file
load_dotenv()

# Define and connect to a new Web3 provider
w3 = Web3(Web3.HTTPProvider(os.getenv("WEB3_PROVIDER_URI")))


################################################################################
# Load Contract
################################################################################

# import ABI file
with open(Path('./contracts/compiled/irrevocableTrust_ABI.json')) as f:
        timeLock_ABI = json.load(f)

# import bytecode object
timeLock_bytecode = "..."

# Create Contract Class Object
@st.cache(allow_output_mutation=True)
def load_contract():

    # Load the Contract
    contract = w3.eth.contract(
        abi=timeLock_ABI,
        bytecode=timeLock_bytecode
    )

    return contract

timeLock_contract = load_contract()


################################################################################
# Display Titles and Wallet Details
################################################################################

# Title
st.title("Irrevocable Time Lock Blockchain Trust")
accounts = w3.eth.accounts

# Use a Streamlit component to get the address of the trustee owner from the user
_trustee = st.sidebar.selectbox("Select Trustee", options=accounts)

# # Use a Streamlit component to get the address of the beneficiary one from the user
_beneficiary1 = st.sidebar.selectbox("Select Beneficiary One", options=accounts)

# # Use a Streamlit component to get the address of the beneficiary two from the user
_beneficiary2 = st.sidebar.selectbox("Select Beneficiary Two", options=accounts)

# Display trustee balance
trustee_balance = str(w3.eth.getBalance(_trustee))
st.write("## Trustee Balance: ")
st.write(f"### {trustee_balance}")
         
# # Display beneficiary1 balance
# beneficiary1_balance = str(w3.eth.getBalance(_beneficiary1))
# st.write("## Beneficiary One Balance: ")
# st.write(f"### {beneficiary1_balance}")

# # Display beneficiary2 balance
# beneficiary2_balance = str(w3.eth.getBalance(_beneficiary2))
# st.write("## Beneficiary Two Balance: ")
# st.write(f"### {beneficiary2_balance}")

# User selects amount to deposit into contract
transaction_amount = st.text_input("Deposit Into Contract Amount")


################################################################################
# Create and Deploy Contract
################################################################################

# Transactions must be signed with private key
private_key = st.text_input("Trustee Private Key")

_beneficiary1_key = st.text_input("Beneficiary One Private Key")

_beneficiary2_key = st.text_input("Beneficiary Two Private Key")

waitingPeriod = st.text_input("Waiting Period")

paymentPerPayoutPeriod = st.text_input("Payment")

st.write("Initial payout interval")
#waitingPeriod = 1
st.write("Time Interval")
#paymentPerPayoutPeriod = 1000

#_beneficiary1 = st.text_input("Initial Waiting Period For First Withdrawal")

#_beneficiary2 = st.text_input("Waiting Period Between Withdrawals")

#trying to cast variables to proper type
#_trustee_ABI = w3.toChecksumAddress(_trustee)

#_beneficiary1_ABI = w3.toChecksumAddress(_beneficiary1)

#_beneficiary2_ABI = w3.toChecksumAddress(_beneficiary2)



# Nonce for security
nonce = w3.eth.getTransactionCount(_trustee)

# Push to start Contract Deployment
if st.button("Deploy Contract"):
    
    # Constructor
    transaction = timeLock_contract.constructor(_trustee, _beneficiary1, _beneficiary2, int(waitingPeriod), int(paymentPerPayoutPeriod)).buildTransaction({"gasPrice": w3.eth.gas_price,"chainId": 1337, "from": _trustee,"nonce": nonce})
    st.write(transaction)
    
    # Sign transaction with private key
    signed_transaction = w3.eth.account.sign_transaction(transaction, private_key=str(private_key))
    st.write("#### Contract Transaction Signed!")
    
    # Send signed transaction
    transaction_hash = w3.eth.send_raw_transaction(signed_transaction.rawTransaction)
    st.write("#### Signed Transaction Sent!")
    
    # Don't forget your receipt
    transaction_receipt = w3.eth.waitForTransactionReceipt(transaction_hash)
    st.write(transaction_receipt)
    
    ################################################################################
    # Use the timelock contract functions from Solidity
    # each function that changes contract state must be;
    # paid for, signed, sent, and received(via receipt)
    ################################################################################
    
    # Create contract instance
    timelock_contract_instance = w3.eth.contract(address=transaction_receipt.contractAddress, abi=timeLock_ABI)
    
#     #Transact payable solidity function deposit that moves ETH from wallet to contract
    receiveMoneyTransaction = timelock_contract_instance.functions.deposit().buildTransaction(
     {
    "gasPrice": w3.eth.gas_price,
    'from': _trustee,
    'value': int(transaction_amount),
    'chainId': 1337,
    'nonce': nonce + 1}
    )
         # Sign transaction again
    receiveMoneysigned_transaction = w3.eth.account.sign_transaction(receiveMoneyTransaction, private_key=str(private_key))
    st.write("#### Receive Money Transaction Signed!")
    
     # Send transaction
    receiveMoneytransaction_hash = w3.eth.send_raw_transaction(receiveMoneysigned_transaction.rawTransaction)
    st.write("#### Receive Money Transaction Sent!")
    
    # Get receipt
    receiveMoneytransaction_receipt = w3.eth.waitForTransactionReceipt(receiveMoneytransaction_hash)
    st.write("#### Receive Money Receipt")
    st.write(receiveMoneytransaction_receipt)
    
#     # Display contract address
#     contract_address = str(timelock_contract_instance.address)
#     st.write("## Contract Address: ")
#     st.write(f"### {contract_address}")
    
#     # Display contract balance
#     contract_balance = w3.eth.getBalance(contract_address)
#     st.write("## Contract Balance: ")
#     st.write(f"### {contract_balance}")   
    
    
    
    
    
    
    # NOT WORKING YET
    #withdraw solidity function that moves ETH from contract back to wallet after duration
    transaction_index = 1 
    st.button("Withdraw From Contract"):
    
    withdrawal = timelock_contract_instance.functions.withdraw().buildTransaction(
     {
        "gasPrice" : w3.eth.gas_price,
        "chainID" : 1337,
        "from" : _beneficiary1,
         #"to": transaction_receipt.contractAddress,
        "nonce" : nonce + transaction_index }
    )
    transaction_index += 1

    withdrawal_transaction = w3.eth.account.sign_transaction(withdrawal_transaction, private_key=str(_beneficiary1_key, _beneficiary2_key))
    st.write("#### Withdraw Transaction Signed!")



    withdrawal_hash = w3.eth.send_raw_transaction(withdrawal_transaction.rawTransaction)
    st.write("#### Receive Money Transaction Sent!")


    withdrawal_receipt = w3.eth.waitForTransactionReceipt(withdrawal_hash)
    st.write("#### Withdrawal Receipt")
    st.write(withdrawal_receipt)
# Out:
#   File "C:\Users\Luke\AppData\Local\Temp\ipykernel_15484\3625310203.py", line 187
#     st.button("Withdraw From Contract"):
#                                         ^
# SyntaxError: invalid syntax
